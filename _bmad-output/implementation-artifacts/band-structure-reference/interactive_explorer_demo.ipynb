# %% [markdown]
# # Interactive 2D Kronig-Penney Explorer
#
# Run the cell below to launch sliders for `V0`, lattice constant `a`, fill fraction, `n_max`, k-path resolution, and plotted bands.

# %%
from interactive_explorer import create_interactive_explorer

create_interactive_explorer()
# Out:
# VBox(children=(HBox(children=(FloatSlider(value=2.0, continuous_update=False, description='V0', max=6.0), Floa…
# Output()
# Output()
# VBox(children=(HBox(children=(FloatSlider(value=2.0, continuous_update=False, description='V0', max=6.0), Floa…
